# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from transformers import BertTokenizer

# %%
df = pd.read_csv("hf://datasets/merve/poetry/poetry.csv")

# %%
df
# Out:
#                                       author  \
# 0                        WILLIAM SHAKESPEARE
# 1    DUCHESS OF NEWCASTLE MARGARET CAVENDISH
# 2                             THOMAS BASTARD
# 3                             EDMUND SPENSER
# 4                          RICHARD BARNFIELD
# ..                                       ...
# 568                            SARA TEASDALE
# 569                               HART CRANE
# 570                     WILLIAM BUTLER YEATS
# 571                            CARL SANDBURG
# 572                        RICHARD ALDINGTON
#
#                                                content  \
# 0    Let the bird of loudest lay\r\nOn the sole Ara...
# 1    Sir Charles into my chamber coming in,\r\nWhen...
# 2    Our vice runs beyond all that old men saw,\r\n...
# 3    Lo I the man, whose Muse whilome did maske,\r\...
# 4    Long have I longd to see my love againe,\r\nSt...
# ..                                                 ...
# 568  With the man I love who loves me not,\r\nI wal...
# 569  Hart Crane, "Voyages I, II, III, IV, V, VI" fr...
# 570  When you are old and grey and full of sleep,\r...
# 571  Give me hunger,\r\nO you gods that sit and giv...
# 572  Potuia, potuia\r\nWhite grave goddess,\r\nPity...
#
#                                    poem name          age  \
# 0                 The Phoenix and the Turtle  Renaissance
# 1                   An Epilogue to the Above  Renaissance
# 2                         Book 7, Epigram 42  Renaissance
# 3    from The Faerie Queene: Book I, Canto I  Renaissance
# 4                                  Sonnet 16  Renaissance
# ..                                       ...          ...
# 568                             Union Square       Modern
# 569                                  Voyages       Modern
# 570                         When You Are Old       Modern
# 571                              At a Window       Modern
# 572                        To a Greek Marble       Modern
#
#                      type
# 0    Mythology & Folklore
# 1    Mythology & Folklore
# 2    Mythology & Folklore
# 3    Mythology & Folklore
# 4    Mythology & Folklore
# ..                    ...
# 568                  Love
# 569                  Love
# 570                  Love
# 571                  Love
# 572                  Love
#
# [573 rows x 5 columns]

# %%
df['training set'] = '<|theme|> ' + df['type'] + ' <|title|> ' + df['poem name'] + ' <|poem|> ' + df['content']
df
# Out:
#                                       author  \
# 0                        WILLIAM SHAKESPEARE
# 1    DUCHESS OF NEWCASTLE MARGARET CAVENDISH
# 2                             THOMAS BASTARD
# 3                             EDMUND SPENSER
# 4                          RICHARD BARNFIELD
# ..                                       ...
# 568                            SARA TEASDALE
# 569                               HART CRANE
# 570                     WILLIAM BUTLER YEATS
# 571                            CARL SANDBURG
# 572                        RICHARD ALDINGTON
#
#                                                content  \
# 0    Let the bird of loudest lay\r\nOn the sole Ara...
# 1    Sir Charles into my chamber coming in,\r\nWhen...
# 2    Our vice runs beyond all that old men saw,\r\n...
# 3    Lo I the man, whose Muse whilome did maske,\r\...
# 4    Long have I longd to see my love againe,\r\nSt...
# ..                                                 ...
# 568  With the man I love who loves me not,\r\nI wal...
# 569  Hart Crane, "Voyages I, II, III, IV, V, VI" fr...
# 570  When you are old and grey and full of sleep,\r...
# 571  Give me hunger,\r\nO you gods that sit and giv...
# 572  Potuia, potuia\r\nWhite grave goddess,\r\nPity...
#
#                                    poem name          age  \
# 0                 The Phoenix and the Turtle  Renaissance
# 1                   An Epilogue to the Above  Renaissance
# 2                         Book 7, Epigram 42  Renaissance
# 3    from The Faerie Queene: Book I, Canto I  Renaissance
# 4                                  Sonnet 16  Renaissance
# ..                                       ...          ...
# 568                             Union Square       Modern
# 569                                  Voyages       Modern
# 570                         When You Are Old       Modern
# 571                              At a Window       Modern
# 572                        To a Greek Marble       Modern
#
#                      type                                       training set
# 0    Mythology & Folklore  <|theme|> Mythology & Folklore <|title|> The P...
# 1    Mythology & Folklore  <|theme|> Mythology & Folklore <|title|> An Ep...
# 2    Mythology & Folklore  <|theme|> Mythology & Folklore <|title|> Book ...
# 3    Mythology & Folklore  <|theme|> Mythology & Folklore <|title|> from ...
# 4    Mythology & Folklore  <|theme|> Mythology & Folklore <|title|> Sonne...
# ..                    ...                                                ...
# 568                  Love  <|theme|> Love <|title|> Union Square <|poem|>...
# 569                  Love  <|theme|> Love <|title|> Voyages <|poem|> Hart...
# 570                  Love  <|theme|> Love <|title|> When You Are Old <|po...
# 571                  Love  <|theme|> Love <|title|> At a Window <|poem|> ...
# 572                  Love  <|theme|> Love <|title|> To a Greek Marble <|p...
#
# [573 rows x 6 columns]

# %%
tokenizer = BertTokenizer.from_pretrained("google-bert/bert-base-uncased")

# %%
special_tokens = {
    "additional_special_tokens": ["<|theme|>", "<|title|>" ,"<|poem|>"]
}
tokenizer.add_special_tokens(special_tokens)

# After adding special tokens (if you did)
vocab_size = len(tokenizer)  # ✅ Correct vocab size

# %%
texts = df['training set'].fillna("").astype(str).tolist()

# Tokenize (with padding + truncation)
encoding = tokenizer(
    texts,
    padding=True,
    truncation=True,
    return_tensors='pt'  # this ensures output is a PyTorch tensor
)

# %%
input_ids = encoding['input_ids']  # shape: (batch_size, seq_len)

# %%
def positional_encoding(length, depth):
  depth = depth/2

  positions = np.arange(length)[:, np.newaxis]
  depths = np.arange(depth)[np.newaxis, :]/depth

  angle_rates = 1 / (10000**depths)
  angle_rads = positions * angle_rates

  pos_encoding = np.concatenate(
      [np.sin(angle_rads), np.cos(angle_rads)],
      axis=-1)

  return tf.cast(pos_encoding, dtype=tf.float32)

# %%
class PositionalEmbedding(tf.keras.layers.Layer):
  def __init__(self, vocab_size, d_model):
    super().__init__()
    self.d_model = d_model
    self.embedding = tf.keras.layers.Embedding(vocab_size, d_model, mask_zero=True)
    self.pos_encoding = positional_encoding(length=2048, depth=d_model)

  def compute_mask(self, *args, **kwargs):
    return self.embedding.compute_mask(*args, **kwargs)

  def call(self, x):
    length = tf.shape(x)[1]
    x = self.embedding(x)
    # This factor sets the relative scale of the embedding and positonal_encoding.
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x = x + self.pos_encoding[tf.newaxis, :length, :]
    return x

# %%
class BaseAttention(tf.keras.layers.Layer):
  def __init__(self, **kwargs):
    super().__init__()
    self.mha = tf.keras.layers.MultiHeadAttention(**kwargs)
    self.layernorm = tf.keras.layers.LayerNormalization()
    self.add = tf.keras.layers.Add()

# %%
class CausalSelfAttention(BaseAttention):
  def call(self, x):
    attn_output = self.mha(
        query=x,
        value=x,
        key=x,
        use_causal_mask = True)
    x = self.add([x, attn_output])
    x = self.layernorm(x)
    return x

# %%
class GlobalSelfAttention(BaseAttention):
  def call(self, x):
    attn_output = self.mha(
        query=x,
        value=x,
        key=x)
    x = self.add([x, attn_output])
    x = self.layernorm(x)
    return x

# %%
class FeedForward(tf.keras.layers.Layer):
  def __init__(self, d_model, dff, dropout_rate=0.1):
    super().__init__()
    self.seq = tf.keras.Sequential([
      tf.keras.layers.Dense(dff, activation='relu'),
      tf.keras.layers.Dense(d_model),
      tf.keras.layers.Dropout(dropout_rate)
    ])
    self.add = tf.keras.layers.Add()
    self.layer_norm = tf.keras.layers.LayerNormalization()

  def call(self, x):
    x = self.add([x, self.seq(x)])
    x = self.layer_norm(x)
    return x

# %%
class DecoderLayer(tf.keras.layers.Layer):
  def __init__(self,
               *,
               d_model,
               num_heads,
               dff,
               dropout_rate=0.1):
    super(DecoderLayer, self).__init__()

    self.causal_self_attention = CausalSelfAttention(
        num_heads=num_heads,
        key_dim=d_model,
        dropout=dropout_rate)

    self.ffn = FeedForward(d_model, dff)

  def call(self, x):
    x = self.causal_self_attention(x=x)

    # Cache the last attention scores for plotting later
    self.last_attn_scores = x

    x = self.ffn(x)  # Shape `(batch_size, seq_len, d_model)`.
    return x

# %%
class Decoder(tf.keras.layers.Layer):
  def __init__(self, *, num_layers, d_model, num_heads, dff, vocab_size,
               dropout_rate=0.1):
    super(Decoder, self).__init__()

    self.d_model = d_model
    self.num_layers = num_layers

    self.pos_embedding = PositionalEmbedding(vocab_size=vocab_size,
                                             d_model=d_model)
    self.dropout = tf.keras.layers.Dropout(dropout_rate)
    self.dec_layers = [
        DecoderLayer(d_model=d_model, num_heads=num_heads,
                     dff=dff, dropout_rate=dropout_rate)
        for _ in range(num_layers)]

  def call(self, x):
    # `x` is token-IDs shape (batch, target_seq_len)
    x = self.pos_embedding(x)  # (batch_size, target_seq_len, d_model)

    x = self.dropout(x)

    for i in range(self.num_layers):
      x  = self.dec_layers[i](x)


    # The shape of x is (batch_size, target_seq_len, d_model).
    return x

# %%
class Transformer(tf.keras.Model):
  def __init__(self, *, num_layers, d_model, num_heads, dff,
               input_vocab_size, target_vocab_size, dropout_rate=0.1):
    super().__init__()

    self.decoder = Decoder(num_layers=num_layers, d_model=d_model,
                           num_heads=num_heads, dff=dff,
                           vocab_size=target_vocab_size,
                           dropout_rate=dropout_rate)

    self.final_layer = tf.keras.layers.Dense(target_vocab_size)

  def call(self, inputs):
    # To use a Keras model with `.fit` you must pass all your inputs in the
    # first argument.
    x  = inputs

    x = self.decoder(x)  # (batch_size, target_len, d_model)

    # Final linear layer output.
    logits = self.final_layer(x)  # (batch_size, target_len, target_vocab_size)

    try:
      # Drop the keras mask, so it doesn't scale the losses/metrics.
      # b/250038731
      del logits._keras_mask
    except AttributeError:
      pass

    # Return the final output and the attention weights.
    return logits

# %%
num_layers = 4
d_model = 128
dff = 512
num_heads = 8
dropout_rate = 0.1

# %%
transformer = Transformer(
    num_layers=num_layers,
    d_model=d_model,
    num_heads=num_heads,
    dff=dff,
    input_vocab_size=vocab_size,
    target_vocab_size=vocab_size,
    dropout_rate=dropout_rate)

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
  def __init__(self, d_model, warmup_steps=4000):
    super().__init__()

    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps

  def __call__(self, step):
    step = tf.cast(step, dtype=tf.float32)
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps ** -1.5)

    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)

optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98,
                                     epsilon=0.1)

# %%
def masked_loss(label, pred):
  mask = label != 0
  loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')
  loss = loss_object(label, pred)

  mask = tf.cast(mask, dtype=loss.dtype)
  loss *= mask

  loss = tf.reduce_sum(loss)/tf.reduce_sum(mask)
  return loss


def masked_accuracy(label, pred):
  pred = tf.argmax(pred, axis=2)
  label = tf.cast(label, pred.dtype)
  match = label == pred

  mask = label != 0

  match = match & mask

  match = tf.cast(match, dtype=tf.float32)
  mask = tf.cast(mask, dtype=tf.float32)
  return tf.reduce_sum(match)/tf.reduce_sum(mask)

# %%
transformer.compile(
    loss=masked_loss,
    optimizer=optimizer,
    metrics=[masked_accuracy])

# %%
inputs = input_ids[:, :-1]  # remove last token
labels = input_ids[:, 1:]   # remove first token

# %%
print(inputs.shape)   # should be (batch_size, seq_len - 1)
print(labels.shape)  # should match
# Out:
# torch.Size([573, 511])
# torch.Size([573, 511])

# %%
dataset = tf.data.Dataset.from_tensor_slices((inputs, labels))
dataset = dataset.batch(32).shuffle(100).prefetch(tf.data.AUTOTUNE)

# %%
transformer.fit(x=inputs, y=labels, epochs=100)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:938: UserWarning: Layer 'causal_self_attention_40' (of type CausalSelfAttention) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:938: UserWarning: Layer 'decoder_layer_48' (of type DecoderLayer) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 31s 763ms/step - loss: 5.1129 - masked_accuracy: 0.2030
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 440ms/step - loss: 5.1256 - masked_accuracy: 0.2014
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 455ms/step - loss: 5.1224 - masked_accuracy: 0.2015
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 452ms/step - loss: 5.1092 - masked_accuracy: 0.2004
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 445ms/step - loss: 5.1046 - masked_accuracy: 0.2022
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 431ms/step - loss: 5.1105 - masked_accuracy: 0.2009
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 426ms/step - loss: 5.1213 - masked_accuracy: 0.1993
# Epoch 8/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 425ms/step - loss: 5.1288 - masked_accuracy: 0.1973
# Epoch 9/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 428ms/step - loss: 5.1249 - masked_accuracy: 0.2006
# Epoch 10/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 435ms/step - loss: 5.1496 - masked_accuracy: 0.1984
# Epoch 11/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - loss: 5.1045 - masked_accuracy: 0.2006
# Epoch 12/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - loss: 5.1208 - masked_accuracy: 0.2010
# Epoch 13/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - loss: 5.0893 - masked_accuracy: 0.2014
# Epoch 14/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 437ms/step - loss: 5.1188 - masked_accuracy: 0.2003
# Epoch 15/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - loss: 5.1272 - masked_accuracy: 0.1989
# Epoch 16/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 434ms/step - loss: 5.1186 - masked_accuracy: 0.2011
# Epoch 17/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 431ms/step - loss: 5.1227 - masked_accuracy: 0.2001
# Epoch 18/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 433ms/step - loss: 5.1242 - masked_accuracy: 0.2018
# Epoch 19/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 433ms/step - loss: 5.1050 - masked_accuracy: 0.2028
# Epoch 20/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 433ms/step - loss: 5.1288 - masked_accuracy: 0.1995
# Epoch 21/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 437ms/step - loss: 5.1097 - masked_accuracy: 0.2019
# Epoch 22/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 440ms/step - loss: 5.1341 - masked_accuracy: 0.2000
# Epoch 23/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - loss: 5.1146 - masked_accuracy: 0.2020
# Epoch 24/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 437ms/step - loss: 5.1214 - masked_accuracy: 0.1993
# Epoch 25/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - loss: 5.1095 - masked_accuracy: 0.2017
# Epoch 26/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 431ms/step - loss: 5.1008 - masked_accuracy: 0.2034
# Epoch 27/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 433ms/step - loss: 5.1092 - masked_accuracy: 0.2028
# Epoch 28/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - loss: 5.1089 - masked_accuracy: 0.2009
# Epoch 29/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 435ms/step - loss: 5.1005 - masked_accuracy: 0.2013
# Epoch 30/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 433ms/step - loss: 5.1283 - masked_accuracy: 0.2015
# Epoch 31/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 437ms/step - loss: 5.0873 - masked_accuracy: 0.2035
# Epoch 32/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 434ms/step - loss: 5.0884 - masked_accuracy: 0.2032
# Epoch 33/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - loss: 5.1070 - masked_accuracy: 0.2026
# Epoch 34/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - loss: 5.1184 - masked_accuracy: 0.1992
# Epoch 35/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - loss: 5.1316 - masked_accuracy: 0.2011
# Epoch 36/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 434ms/step - loss: 5.1146 - masked_accuracy: 0.2009
# Epoch 37/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - loss: 5.0989 - masked_accuracy: 0.2054
# Epoch 38/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 436ms/step - loss: 5.1085 - masked_accuracy: 0.2021
# Epoch 39/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - loss: 5.1085 - masked_accuracy: 0.2023
# Epoch 40/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 433ms/step - loss: 5.0962 - masked_accuracy: 0.2002
# Epoch 41/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 436ms/step - loss: 5.1226 - masked_accuracy: 0.2019
# Epoch 42/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 438ms/step - loss: 5.0996 - masked_accuracy: 0.2022
# Epoch 43/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 431ms/step - loss: 5.0980 - masked_accuracy: 0.2022
# Epoch 44/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 430ms/step - loss: 5.0996 - masked_accuracy: 0.2014
# Epoch 45/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 429ms/step - loss: 5.1188 - masked_accuracy: 0.2028
# Epoch 46/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - loss: 5.0931 - masked_accuracy: 0.2052
# Epoch 47/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 433ms/step - loss: 5.0971 - masked_accuracy: 0.2024
# Epoch 48/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 436ms/step - loss: 5.0983 - masked_accuracy: 0.2040
# Epoch 49/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 437ms/step - loss: 5.0656 - masked_accuracy: 0.2043
# Epoch 50/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - loss: 5.1023 - masked_accuracy: 0.2025
# Epoch 51/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 433ms/step - loss: 5.1195 - masked_accuracy: 0.2018
# Epoch 52/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - loss: 5.0912 - masked_accuracy: 0.2022
# Epoch 53/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 434ms/step - loss: 5.0804 - masked_accuracy: 0.2052
# Epoch 54/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 433ms/step - loss: 5.0871 - masked_accuracy: 0.2036
# Epoch 55/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 434ms/step - loss: 5.0928 - masked_accuracy: 0.2055
# Epoch 56/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 436ms/step - loss: 5.0831 - masked_accuracy: 0.2022
# Epoch 57/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 438ms/step - loss: 5.0932 - masked_accuracy: 0.2039
# Epoch 58/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - loss: 5.0796 - masked_accuracy: 0.2069
# Epoch 59/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 433ms/step - loss: 5.1156 - masked_accuracy: 0.2022
# Epoch 60/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - loss: 5.1234 - masked_accuracy: 0.1997
# Epoch 61/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 431ms/step - loss: 5.0905 - masked_accuracy: 0.2055
# Epoch 62/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - loss: 5.0637 - masked_accuracy: 0.2045
# Epoch 63/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 434ms/step - loss: 5.0877 - masked_accuracy: 0.2062
# Epoch 64/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 434ms/step - loss: 5.1037 - masked_accuracy: 0.2042
# Epoch 65/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 433ms/step - loss: 5.0804 - masked_accuracy: 0.2049
# Epoch 66/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 437ms/step - loss: 5.1132 - masked_accuracy: 0.2022
# Epoch 67/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 434ms/step - loss: 5.0687 - masked_accuracy: 0.2094
# Epoch 68/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 437ms/step - loss: 5.0784 - masked_accuracy: 0.2041
# Epoch 69/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 438ms/step - loss: 5.0748 - masked_accuracy: 0.2045
# Epoch 70/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 431ms/step - loss: 5.0759 - masked_accuracy: 0.2067
# Epoch 71/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 428ms/step - loss: 5.0821 - masked_accuracy: 0.2042
# Epoch 72/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 430ms/step - loss: 5.1037 - masked_accuracy: 0.2044
# Epoch 73/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 431ms/step - loss: 5.0790 - masked_accuracy: 0.2032
# Epoch 74/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 433ms/step - loss: 5.0712 - masked_accuracy: 0.2045
# Epoch 75/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 437ms/step - loss: 5.0557 - masked_accuracy: 0.2055
# Epoch 76/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 441ms/step - loss: 5.0641 - masked_accuracy: 0.2085
# Epoch 77/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 436ms/step - loss: 5.0570 - masked_accuracy: 0.2073
# Epoch 78/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 433ms/step - loss: 5.0713 - masked_accuracy: 0.2055
# Epoch 79/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - loss: 5.0888 - masked_accuracy: 0.2063
# Epoch 80/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - loss: 5.0979 - masked_accuracy: 0.2053
# Epoch 81/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 431ms/step - loss: 5.0604 - masked_accuracy: 0.2063
# Epoch 82/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - loss: 5.0599 - masked_accuracy: 0.2069
# Epoch 83/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - loss: 5.0757 - masked_accuracy: 0.2064
# Epoch 84/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 433ms/step - loss: 5.0704 - masked_accuracy: 0.2058
# Epoch 85/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 433ms/step - loss: 5.0771 - masked_accuracy: 0.2062
# Epoch 86/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 434ms/step - loss: 5.0784 - masked_accuracy: 0.2051
# Epoch 87/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - loss: 5.0888 - masked_accuracy: 0.2037
# Epoch 88/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 433ms/step - loss: 5.0663 - masked_accuracy: 0.2070
# Epoch 89/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 435ms/step - loss: 5.0745 - masked_accuracy: 0.2037
# Epoch 90/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - loss: 5.0351 - masked_accuracy: 0.2063
# Epoch 91/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 431ms/step - loss: 5.0635 - masked_accuracy: 0.2084
# Epoch 92/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 429ms/step - loss: 5.0890 - masked_accuracy: 0.2051
# Epoch 93/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 433ms/step - loss: 5.0737 - masked_accuracy: 0.2085
# Epoch 94/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 434ms/step - loss: 5.0600 - masked_accuracy: 0.2077
# Epoch 95/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 434ms/step - loss: 5.0554 - masked_accuracy: 0.2058
# Epoch 96/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 440ms/step - loss: 5.0374 - masked_accuracy: 0.2092
# Epoch 97/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 434ms/step - loss: 5.0671 - masked_accuracy: 0.2047
# Epoch 98/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - loss: 5.0393 - masked_accuracy: 0.2090
# Epoch 99/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - loss: 5.0755 - masked_accuracy: 0.2068
# Epoch 100/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - loss: 5.0509 - masked_accuracy: 0.2103

# %%
output = transformer(inputs[20:21])

# %%
predicted_token_ids = tf.argmax(output, axis=-1)

# %%
decoded_text = tokenizer.decode(predicted_token_ids[0], skip_special_tokens=True)

# %%
decoded_text
# Out:
# "love the : the : the,,se :ssy. i permission., the ande, the, and the,. the love, world., and it the love and, and the the eyes, the -.s,, of the eyesy, the, the the the, world '.ys and the worlds and the, world, the.h,., the, and the the world, the and the,, the,, the of,h,, and the the worlds the inh,,,. and the the world,,,,,, and the lovey, and the world, and the'to the eyess, and, a lovesss,,. the. theeeee,,,,ee,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,.e,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,e,,s,,,,,,,,,,,,,,,,,,,,.eee,,,,,,,,,,,,,,,ee,,,,,,,,,,....,,,,,,,,,,,,,,,,,,,,ee,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,ee,,,,,,,,,,,,e,,,,e,,,,,,eee,,,,,,,,,,,eeee,,,,,,,,,,,,ee,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,.."
